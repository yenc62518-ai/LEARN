# %% [markdown]
# Sau khi dùng **MI** để xác định các features, việc tiếp theo cần làm là **xử lý và chuyển hóa (transform) các features đó**

# %%
import pandas as pd
data = pd.read_csv("./train.csv")
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
X = data.copy()
y = X.pop("SalePrice")
X.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# TẠO CÁC CỘT MỚI ĐỐI VỚI CÁC BIẾN LIÊN TỤC

# %%
X_1 = pd.DataFrame()

X_1["Age"] = X['YrSold'] - X['YearBuilt']
X_1["RemodAge"] = X['YrSold'] - X['YearRemodAdd']
X_1["TotalSF"] = X['TotalBsmtSF'] + X['1stFlrSF'] + X['2ndFlrSF']
X_1["TotalOutsideSF"] =  X.OpenPorchSF + X.EnclosedPorch + X['3SsnPorch'] + X.ScreenPorch
X_1["TotalBathrooms"] = X.FullBath + (0.5 * X.HalfBath) + X.BsmtFullBath + (0.5 * X.BsmtHalfBath)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# TẠO INTERACTION FEATURES : ONE-HOT CỘT CAT, MULTIPLY VỚI CONTINUOUS FEATURES VÀ GỘP LẠI VÀO X
# KĨ THUẬT NÂNG CAO NÊN CHƯA CẦN SỬ DỤNG NẾU KHÔNG QUẢN LÝ ĐƯỢC DATA

# %%
# Categorical = X.select_dtypes(exclude=['number']).columns
# Num = X.select_dtypes(include=['number']).columns
# Continuous = []
# for col in X[Num]: 
#     if X[col].nunique() > 15:
#         Continuous.append(col)
# X_new = X[Categorical].copy()
# X_new = pd.get_dummies(X_new, drop_first=True).astype(int) # one-hot encoding
# for cat in X_new.columns:
#     for cont in Continuous:
#         X_new[cat + "_" + cont] = X_new[cat] * X[cont] # interaction feature
# # Cách cơ bản, nhưng rất chậm

# %% [markdown]
# COUNT : ĐẾM SỐ LƯỢNG PORCH 1 NHÀ CÓ THỂ CÓ

# %%
count = [col for col in X.columns if 'Porch' in col]
X['Porch'] = X[count].gt(0).sum(axis=1)

# %% [markdown]
# BREAK DOWN : PHÂN TÍCH CHUỖI

# %% [markdown]
# GROUP TRANSFORMATION : gom giá trị như trung bình, trung vị, min, max,... theo từng nhóm
